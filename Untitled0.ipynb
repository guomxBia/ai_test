# %%
# !git status
# Out:
# ^C

# %%
# !git status
# Out:
# Refresh index: 100% (179/179), done.
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	Untitled0.ipynb
# 	abc.txt
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# %cd /content/drive/MyDrive/ColabNotebooks/ai_test
# Out:
# /content/drive/MyDrive/ColabNotebooks/ai_test
